# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("R:\\Image Classification\\model\\Dataset\\rishi\\20220325_162355.jpg")
img.shape
# Out:
# (2640, 1980, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (2640, 1980)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier("R:\Image Classification\Harcascade\haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("R:\Image Classification\Harcascade\haarcascade_eye.xml")

faces = face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[734, 743, 707, 707]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (734, 743, 707, 707)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (707, 707, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread("R:\\Image Classification\\model\\Dataset\\rishi\\20220325_162355.jpg")
plt.imshow(original_image)

# %%
path_to_data = "R:\\Image Classification\\model\\Dataset"
path_to_cr_data = "R:\\Image Classification\\model\\cropped"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['R:\\Image Classification\\model\\Dataset\\ntr jr - Google Search',
#  'R:\\Image Classification\\model\\Dataset\\rishi']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('\\')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "\\" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  R:\Image Classification\model\croppedntr jr - Google Search
# Generating cropped images in folder:  R:\Image Classification\model\croppedrishi

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('\\')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'croppedntr jr - Google Search': ['R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search1.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search10.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search11.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search12.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search13.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search14.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search15.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search16.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search17.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search18.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search19.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search2.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search20.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search21.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search22.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search23.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search24.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search25.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search26.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search27.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search28.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search29.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search3.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search30.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search31.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search32.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search33.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search34.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search35.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search36.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search37.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search38.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search39.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search4.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search40.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search41.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search42.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search43.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search44.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search45.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search46.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search47.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search48.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search49.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search5.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search50.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search51.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search6.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search7.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search8.png',
#   'R:\\Image Classification\\model\\croppedntr jr - Google Search\\ntr jr - Google Search9.png'],
#  'croppedrishi': ['R:\\Image Classification\\model\\croppedrishi\\rishi1.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi10.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi11.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi12.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi13.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi14.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi15.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi16.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi17.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi18.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi19.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi2.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi20.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi21.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi22.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi23.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi24.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi25.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi26.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi27.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi28.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi29.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi3.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi30.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi31.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi32.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi4.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi5.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi6.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi7.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi8.png',
#   'R:\\Image Classification\\model\\croppedrishi\\rishi9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'croppedntr jr - Google Search': 0, 'croppedrishi': 1}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (83, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.9047619047619048

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        12
#            1       0.89      0.89      0.89         9
#
#     accuracy                           0.90        21
#    macro avg       0.90      0.90      0.90        21
# weighted avg       0.90      0.90      0.90        21

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.952564
# 1        random_forest    0.905128
# 2  logistic_regression    0.937179
#
#                                     best_params
# 0          {'svc__C': 10, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc', SVC(C=10, gamma='auto', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9047619047619048

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.8571428571428571

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8571428571428571

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[11,  1],
#        [ 1,  8]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'croppedntr jr - Google Search': 0, 'croppedrishi': 1}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\rishi chaitanya\appdata\roaming\python\python39\site-packages (1.0.1)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
